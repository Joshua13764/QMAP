# %%
import matplotlib.pyplot as plt
from statsmodels.base.model import GenericLikelihoodModel
import cv2
import scienceplots
import tifffile as tiff

from boulder_statistics.analysis.data_product_encyclopedia import DataProductEncyclopedia
plt.style.use('science')
plt.rcParams["figure.figsize"] = (3.5, 3.5 * ((5**0.5 - 1) / 2)) # 3.5
plt.rcParams["figure.dpi"] = 600
# %matplotlib inline

import polars as pl
from polars import Expr, LazyFrame, DataFrame
import numpy as np
from pathlib import Path
from typing import Any
import tifffile
from typing import Dict
from typing import Callable


from boulder_statistics.analysis.data_product_encyclopedia import DataProductEncyclopedia

dp = DataProductEncyclopedia(
    data_products_path=Path(r"C:\Users\Joshu\OneDrive - Nexus365\AO33\Boulder_database\AO33\.data_products"))

# %%
combined_db_export_pool = Path("combined_db_export_pool")
combined_db_pass_00_export_folder: Path = combined_db_export_pool / "pass_00"
export_pool = Path("agg_export_pool/pass_00")
export_pool.mkdir(exist_ok=True, parents=True)

# %%
# pl.scan_parquet(export_folder).group_by("boulder_id").agg().collect()

filter_df = pl.scan_parquet(combined_db_pass_00_export_folder).filter(pl.col("boulder_id") < 40).collect()
filter_df.head()
# Out:
# shape: (5, 66)
# ┌─────┬──────┬──────┬──────────┬───┬─────────────┬──────────────────┬─────────────────┬────────────┐
# │ i   ┆ j    ┆ face ┆ area     ┆ … ┆ positions_z ┆ detection_lod_le ┆ detection_lod_c ┆ boulder_id │
# │ --- ┆ ---  ┆ ---  ┆ ---      ┆   ┆ ---         ┆ vel              ┆ ode             ┆ ---        │
# │ u32 ┆ u32  ┆ str  ┆ f32      ┆   ┆ f32         ┆ ---              ┆ ---             ┆ u32        │
# │     ┆      ┆      ┆          ┆   ┆             ┆ u8               ┆ str             ┆            │
# ╞═════╪══════╪══════╪══════════╪═══╪═════════════╪══════════════════╪═════════════════╪════════════╡
# │ 465 ┆ 1674 ┆ posx ┆ 0.001177 ┆ … ┆ -0.141084   ┆ 0                ┆                 ┆ 16         │
# │ 463 ┆ 1711 ┆ posx ┆ 0.001218 ┆ … ┆ -0.141739   ┆ 0                ┆                 ┆ 16         │
# │ 460 ┆ 1733 ┆ posx ┆ 0.001132 ┆ … ┆ -0.142045   ┆ 0                ┆                 ┆ 16         │
# │ 443 ┆ 1713 ┆ posx ┆ 0.000982 ┆ … ┆ -0.142415   ┆ 0                ┆                 ┆ 16         │
# │ 454 ┆ 1669 ┆ posx ┆ 0.001116 ┆ … ┆ -0.141372   ┆ 0                ┆                 ┆ 16         │
# └─────┴──────┴──────┴──────────┴───┴─────────────┴──────────────────┴─────────────────┴────────────┘

# %%
cols_to_group: list[str] = [col_name for col_name in filter_df.columns if "tri_num" in col_name]

for col in cols_to_group:
    print(f"Joining for col {col}")
    df = pl.scan_parquet(combined_db_pass_00_export_folder).select(col).group_by(
        col
    ).agg(pl.len().alias(f"{col} alpha")).collect(engine="streaming")
    df.write_parquet(export_pool / f"{col}.parquet")
# Out:
# Joining for col TIR detailed_survey tri_num
# Joining for col TIR recona tri_num
# Joining for col TIR reconb tri_num
# Joining for col VNIR detailed_survey tri_num
# Joining for col VNIR recona tri_num
# Joining for col VNIR reconc tri_num
