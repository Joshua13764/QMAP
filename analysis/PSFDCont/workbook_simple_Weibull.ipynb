# %%
import matplotlib.pyplot as plt
from statsmodels.base.model import GenericLikelihoodModel
import numpy as np
import cv2
import scienceplots
import tifffile as tiff

from boulder_statistics.analysis.data_product_encyclopedia import DataProductEncyclopedia
from boulder_statistics.analysis.power_law_fit_params import PowerLawFitParams
from boulder_statistics.analysis.weibull_fit_params import WeibullFitParams

plt.style.use('science')
plt.rcParams["figure.figsize"] = (3.5, 3.5 * ((5**0.5 - 1) / 2)) # 3.5
plt.rcParams["figure.dpi"] = 600
# %matplotlib inline

import polars as pl
from polars import Expr, LazyFrame, DataFrame
import numpy as np
from pathlib import Path
from typing import Any
import tifffile
from typing import Dict
from typing import Callable


from boulder_statistics.analysis.data_product_encyclopedia import DataProductEncyclopedia

dp = DataProductEncyclopedia(
    data_products_path=Path(r"C:\Users\Joshu\OneDrive - Nexus365\AO33\Boulder_database\AO33\.data_products"))

# %%
from boulder_statistics.analysis.quick_calculate_Weibull import WeibullFittingFunction

fit = WeibullFittingFunction(dp, LAD_min=0)

# %%
class TheoryFit(GenericLikelihoodModel):
    param_names = ["lambda", "k"]

    def __init__(self, x):
        super().__init__(x)

    def loglikeobs(self, params):
        alphas = self.endog

        fit_params = WeibullFitParams(*params)
        print(f"Ran iteration with params {params}")
        return np.log(fit.F_norm(alphas, fit_params))

    @property
    def start_params(self):
        return np.array([0.1, 0.3])
    
mle_model = TheoryFit(fit.cleaned_data.collect()["alpha"].to_numpy()).fit()

print(mle_model.summary())
mle_model.model.loglikeobs(mle_model.params).mean()
# Out:
# Ran iteration with params [0.1 0.3]
# Ran iteration with params [0.105 0.3  ]
# Ran iteration with params [0.1   0.315]
# Ran iteration with params [0.095 0.315]
# Ran iteration with params [0.09   0.3225]
# Ran iteration with params [0.09   0.3375]
# Ran iteration with params [0.085   0.35625]
# Ran iteration with params [0.075   0.36375]
# Ran iteration with params [0.0625   0.388125]
# Ran iteration with params [0.0575   0.421875]
# Ran iteration with params [0.065625   0.39703125]
# Ran iteration with params [0.043125   0.42890625]
# Ran iteration with params [0.07453125 0.37441406]
# Ran iteration with params [0.07765625 0.38332031]
# Ran iteration with params [0.08523438 0.38091797]
# Ran iteration with params [0.06875   0.4059375]
# Ran iteration with params [0.08078125 0.39222656]
# Ran iteration with params [0.08835938 0.38982422]
# Ran iteration with params [0.0896875  0.36960938]
# Ran iteration with params [0.07398438 0.39685547]
# Ran iteration with params [0.07710938 0.40576172]
# Ran iteration with params [0.07683594 0.41698242]
# Ran iteration with params [0.08390625 0.40113281]
# Ran iteration with params [0.08886719 0.40327148]
# Ran iteration with params [0.08519531 0.41680664]
# Ran iteration with params [0.08740234 0.42909668]
# Ran iteration with params [0.09916016 0.42660645]
# Ran iteration with params [0.11018555 0.43702881]
# Ran iteration with params [0.1087207 0.462854 ]
# Ran iteration with params [0.11864746 0.49264526]
# Ran iteration with params [0.14143066 0.50057739]
# Ran iteration with params [0.16844482 0.53631775]
# Ran iteration with params [0.17690674 0.5919342 ]
# Ran iteration with params [0.2267041  0.63560669]
# Ran iteration with params [0.28073242 0.7070874 ]
# Ran iteration with params [0.21824219 0.57999023]
# Ran iteration with params [0.23890991 0.57401825]
# Ran iteration with params [0.27650146 0.67927917]
# Ran iteration with params [0.19545898 0.57205811]
# Ran iteration with params [0.18699707 0.51644165]
# Ran iteration with params [0.21677734 0.60581543]
# Ran iteration with params [0.19399414 0.5978833 ]
# Ran iteration with params [0.21218018 0.5844635 ]
# Ran iteration with params [0.19086182 0.55070618]
# Ran iteration with params [0.21029846 0.59203812]
# Ran iteration with params [0.19357727 0.57963272]
# Ran iteration with params [0.198228   0.58084042]
# Ran iteration with params [0.21306747 0.60082043]
# Ran iteration with params [0.20866535 0.59362985]
# Ran iteration with params [0.22073582 0.60482755]
# Ran iteration with params [0.20385495 0.5868372 ]
# Ran iteration with params [0.20222184 0.58842893]
# Ran iteration with params [0.19741144 0.58163628]
# Ran iteration with params [0.20585187 0.59063146]
# Ran iteration with params [0.20748498 0.58903973]
# Ran iteration with params [0.2061692  0.58888703]
# Ran iteration with params [0.20417228 0.58509277]
# Ran iteration with params [0.20185803 0.58304294]
# Ran iteration with params [0.20509141 0.58742601]
# Ran iteration with params [0.20477408 0.58917043]
# Ran iteration with params [0.20432273 0.58611219]
# Ran iteration with params [0.20555918 0.58670099]
# Ran iteration with params [0.20428101 0.58680315]
# Ran iteration with params [0.20504969 0.58811697]
# Ran iteration with params [0.20450447 0.58661338]
# Ran iteration with params [0.20369407 0.58599052]
# Ran iteration with params [0.20474207 0.58706713]
# Ran iteration with params [0.20451861 0.5872569 ]
# Ran iteration with params [0.20405755 0.58699291]
# Ran iteration with params [0.20457094 0.58704858]
# Ran iteration with params [0.20433334 0.58659483]
# Ran iteration with params [0.20437966 0.58676034]
# Ran iteration with params [0.20466959 0.58700578]
# Ran iteration with params [0.20437815 0.5868538 ]
# Ran iteration with params [0.20456944 0.58714204]
# Ran iteration with params [0.20452199 0.58704662]
# Ran iteration with params [0.20471478 0.58724139]
# Ran iteration with params [0.20446231 0.5869507 ]
# Ran iteration with params [0.20441336 0.58694874]
# Ran iteration with params [0.20453155 0.58702362]
# Optimization terminated successfully.
#          Current function value: 6.341442
#          Iterations: 42
#          Function evaluations: 80
# Ran iteration with params [0.20451223 0.5869507 ]
# Ran iteration with params [0.20446231 0.5869507 ]
# Ran iteration with params [0.20446231 0.5869507 ]
# Ran iteration with params [0.20441239 0.5869507 ]
# Ran iteration with params [0.20448727 0.58702235]
# Ran iteration with params [0.20448727 0.58687905]
# Ran iteration with params [0.20443735 0.58702235]
# Ran iteration with params [0.20443735 0.58687905]
# Ran iteration with params [0.20446231 0.587094  ]
# Ran iteration with params [0.20446231 0.5869507 ]
# Ran iteration with params [0.20446231 0.5869507 ]
# Ran iteration with params [0.20446231 0.5868074 ]
# Ran iteration with params [0.20446231 0.5869507 ]
#                               TheoryFit Results
# ==============================================================================
# Dep. Variable:                      y   Log-Likelihood:            -2.7021e+06
# Model:                      TheoryFit   AIC:                         5.404e+06
# Method:            Maximum Likelihood   BIC:                         5.404e+06
# Date:                Thu, 25 Jun 2026
# Time:                        15:38:42
# No. Observations:              426096
# Df Residuals:                  426094
# Df Model:                           2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# par0           0.2045      0.001    248.685      0.000       0.203       0.206
# par1           0.5870      0.001    509.199      0.000       0.585       0.589
# ==============================================================================
# Ran iteration with params [0.20446231 0.5869507 ]
# np.float64(-6.341441972498452)

# %%
# 1.6290 0.6006 for LAD min = 2

alphas_hist = np.geomspace(1, 1e6, 100)
alphas = np.geomspace(1, 1e6, 1000)

counts, bins, _ = plt.hist(fit.cleaned_data.collect()["alpha"].to_numpy(),
                           alphas_hist, density = True)

fit_params = WeibullFitParams(*mle_model.params)
# fit_params = WeibullFitParams(lambda_ = 0.5, k = 0.4)
plt.plot(alphas, fit.F_norm(alphas, fit_params), label = r"$F(\alpha|\omega)$")

plt.ylim(1e-7, counts.max() * 1.5)
# plt.xlim(fit.plot_range[0] * 0.7, fit.plot_range[1] * 0.5)
plt.xscale("log")
plt.xlabel(r"$\alpha$")
plt.yscale("log")
plt.ylabel("Det. probability density")
plt.legend()
plt.grid(which='both', linestyle='-', linewidth=0.4, alpha=0.2)
plt.tight_layout()
plt.savefig("overall_fit.png")
plt.show()

# %%
bin_centers = 0.5 * (dp.Phi_counts_smoothed_bins[:-1] + dp.Phi_counts_smoothed_bins[1:])
bin_widths = np.abs(dp.Phi_counts_smoothed_bins[:-1] - dp.Phi_counts_smoothed_bins[1:])
mask = (dp.Phi_counts_smoothed_counts / bin_widths > 10**3) & (dp.Phi_counts_smoothed_counts * bin_widths > 10**3)
plt.plot(bin_centers[mask], dp.Phi_counts_smoothed_counts[mask], label = "Mesh (smoothed)")

bin_centers = 0.5 * (dp.Phi_counts_sphere_noisy_bins[:-1] + dp.Phi_counts_sphere_noisy_bins[1:])
mask = dp.Phi_counts_sphere_noisy_counts != 0
plt.plot(bin_centers[mask], dp.Phi_counts_sphere_noisy_counts[mask], label = "sphere (noisy)")

bin_centers = 0.5 * (dp.Phi_counts_sphere_theory_bins[:-1] + dp.Phi_counts_sphere_theory_bins[1:])
mask = dp.Phi_counts_sphere_theory_counts != 0
plt.plot(bin_centers[mask], dp.Phi_counts_sphere_theory_counts[mask], label = "sphere (theory)")

plt.xscale("log")
plt.yscale("log")
plt.legend()
