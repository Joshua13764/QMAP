# %%
import matplotlib.pyplot as plt
from statsmodels.base.model import GenericLikelihoodModel
import numpy as np
import cv2
import scienceplots
import tifffile as tiff

from boulder_statistics.analysis.data_product_encyclopedia import DataProductEncyclopedia
from boulder_statistics.analysis.fit_params.weibull_fit_params import WeibullFitParams

plt.style.use('science')
plt.rcParams["figure.figsize"] = (3.5, 3.5 * ((5**0.5 - 1) / 2)) # 3.5
plt.rcParams["figure.dpi"] = 600
# %matplotlib inline

import polars as pl
from polars import Expr, LazyFrame, DataFrame
import numpy as np
from pathlib import Path
from typing import Any
import tifffile
from typing import Dict
from typing import Callable


from boulder_statistics.analysis.data_product_encyclopedia import DataProductEncyclopedia

dp = DataProductEncyclopedia(
    data_products_path=Path(r"C:\Users\Joshu\OneDrive - Nexus365\AO33\Boulder_database\AO33\.data_products"))

# %%
from boulder_statistics.analysis.quick_calculate_Weibull import WeibullFittingFunction

fit = WeibullFittingFunction(dp, LAD_min=0)

# %%
from statsmodels.base.model import GenericLikelihoodModelResults


mle_model: GenericLikelihoodModelResults = fit.MLE_fit(
    optimize_params = WeibullFitParams(lambda_ = 0.1, k = 0.4),
    verbose = True
)
# Out:
# Running iteration with params [0.1 0.4]
# Running iteration with params [0.105 0.4  ]
# Running iteration with params [0.1  0.42]
# Running iteration with params [0.095 0.42 ]
# Running iteration with params [0.09 0.43]
# Running iteration with params [0.09 0.45]
# Running iteration with params [0.085 0.475]
# Running iteration with params [0.075 0.485]
# Running iteration with params [0.0625 0.5175]
# Running iteration with params [0.07 0.53]
# Running iteration with params [0.075 0.505]
# Running iteration with params [0.065 0.515]
# Running iteration with params [0.08  0.485]
# Running iteration with params [0.08  0.465]
# Running iteration with params [0.07625 0.495  ]
# Running iteration with params [0.07125 0.495  ]
# Running iteration with params [0.07  0.485]
# Running iteration with params [0.066875 0.48    ]
# Running iteration with params [0.070625 0.47    ]
# Running iteration with params [0.0625 0.465 ]
# Running iteration with params [0.05625 0.455  ]
# Running iteration with params [0.0525 0.465 ]
# Running iteration with params [0.041875 0.44    ]
# Running iteration with params [0.029375 0.42    ]
# Running iteration with params [0.033125 0.41    ]
# Running iteration with params [0.0234375 0.3825   ]
# Running iteration with params [-0.0034375  0.3475   ]
# C:\Users\Joshu\OneDrive - Nexus365\AO33\Boulder_database\AO33\src\boulder_statistics\analysis\quick_calculate_Weibull.py:29: RuntimeWarning: invalid value encountered in power
#   -(
# Running iteration with params [0.04132813 0.428125  ]
# Running iteration with params [0.03539063 0.390625  ]
# Running iteration with params [0.0175 0.345 ]
# Running iteration with params [0.00558594 0.3034375 ]
# Running iteration with params [-0.00636719  0.2953125 ]
# Running iteration with params [0.02495117 0.36679687]
# Running iteration with params [0.00407227 0.31914063]
# Running iteration with params [0.01973145 0.35488281]
# Running iteration with params [0.00187988 0.27582031]
# Running iteration with params [0.00726929 0.30249023]
# Running iteration with params [-0.00687622  0.25104492]
# Running iteration with params [0.01307953 0.32892334]
# Running iteration with params [-2.24304199e-04  2.77004395e-01]
# Running iteration with params [0.00975357 0.3159436 ]
# Running iteration with params [0.00310165 0.28998413]
# Running iteration with params [0.00809059 0.30945374]
# Running iteration with params [0.00977394 0.30850647]
# Running iteration with params [0.00663294 0.30470474]
# Running iteration with params [0.00581163 0.29774124]
# Running iteration with params [0.00467216 0.29188499]
# Running iteration with params [0.00403581 0.2940995 ]
# Running iteration with params [0.00646092 0.30039255]
# Running iteration with params [0.00450013 0.2875728 ]
# Running iteration with params [0.00343373 0.27900683]
# Running iteration with params [0.00164497 0.27049928]
# Running iteration with params [0.00525693 0.29291923]
# Running iteration with params [0.00401851 0.28004107]
# Running iteration with params [0.00219531 0.26612867]
# Running iteration with params [0.0006645  0.25273339]
# Running iteration with params [0.00161053 0.26509444]
# Running iteration with params [0.00341651 0.27630441]
# Running iteration with params [0.00217809 0.26342625]
# Running iteration with params [0.00155027 0.25563596]
# Running iteration with params [0.00095688 0.25325051]
# Running iteration with params [0.00280161 0.27054094]
# Running iteration with params [0.00278439 0.26783852]
# Running iteration with params [0.00216087 0.26072383]
# Running iteration with params [0.0018405  0.25581528]
# Running iteration with params [0.00123421 0.25140301]
# Running iteration with params [0.00239684 0.26372964]
# Running iteration with params [0.00205926 0.25611867]
# Running iteration with params [0.00150292 0.2482043 ]
# Running iteration with params [0.00105596 0.24044164]
# Running iteration with params [0.0008372  0.24013825]
# Running iteration with params [0.00175374 0.25212356]
# Running iteration with params [0.00114272 0.24413335]
# Running iteration with params [0.00035817 0.22875971]
# Running iteration with params [0.00146992 0.24905139]
# Running iteration with params [0.00072875 0.2355236 ]
# Running iteration with params [0.00128463 0.24566944]
# Running iteration with params [0.00119787 0.24197772]
# Running iteration with params [0.0009692  0.23674992]
# Running iteration with params [0.00081148 0.23229016]
# Running iteration with params [0.00066957 0.23075407]
# Running iteration with params [0.00040542 0.22514224]
# Running iteration with params [0.00042509 0.22260259]
# Running iteration with params [0.00089824 0.23598188]
# Running iteration with params [0.00058281 0.22706235]
# Running iteration with params [0.00042509 0.22260259]
# Running iteration with params [0.00044089 0.22552627]
# Running iteration with params [0.00071883 0.23059919]
# Running iteration with params [0.00063207 0.22690747]
# Running iteration with params [0.00049605 0.22337064]
# Running iteration with params [0.00038465 0.21975636]
# Running iteration with params [0.00044678 0.22352552]
# Running iteration with params [0.00058575 0.22606198]
# Running iteration with params [0.00049899 0.22237027]
# Running iteration with params [0.00045708 0.22002422]
# Running iteration with params [0.00036738 0.21733288]
# Running iteration with params [0.00025819 0.21296833]
# Running iteration with params [0.00032841 0.21398646]
# Running iteration with params [0.00024459 0.20929437]
# Running iteration with params [1.54887929e-04 2.06603030e-01]
# Running iteration with params [0.00038153 0.21666892]
# Running iteration with params [0.00025875 0.20863042]
# Running iteration with params [1.21806684e-04 2.01255871e-01]
# Running iteration with params [0.0003166  0.21281566]
# Running iteration with params [0.00030244 0.21347961]
# Running iteration with params [0.00026967 0.20984272]
# Running iteration with params [1.97662333e-04 2.06321433e-01]
# Running iteration with params [0.00028687 0.2111921 ]
# Running iteration with params [0.00031195 0.21174045]
# Running iteration with params [0.00026143 0.20990589]
# Running iteration with params [0.00027862 0.21125528]
# Running iteration with params [0.00025319 0.20996907]
# Running iteration with params [0.00027845 0.21088634]
# Running iteration with params [0.00026125 0.20953696]
# Running iteration with params [0.00024424 0.20855651]
# Running iteration with params [0.00022713 0.20739159]
# Running iteration with params [0.00022731 0.20776052]
# Running iteration with params [0.00025277 0.20909285]
# Running iteration with params [0.00021847 0.20657855]
# Running iteration with params [1.96983984e-04 2.04914876e-01]
# Running iteration with params [1.92829932e-04 2.04877288e-01]
# Running iteration with params [0.00023778 0.20803896]
# Running iteration with params [0.00020781 0.20593118]
# Running iteration with params [0.00023029 0.20751201]
# Running iteration with params [0.00022163 0.20669897]
# Running iteration with params [0.0002098  0.20576551]
# Running iteration with params [1.99558025e-04 2.04892252e-01]
# Running iteration with params [1.96398005e-04 2.04771827e-01]
# Running iteration with params [1.77490077e-04 2.03085531e-01]
# Running iteration with params [0.00020822 0.20570529]
# Running iteration with params [0.00021138 0.20582572]
# Running iteration with params [2.00144005e-04 2.05035300e-01]
# Running iteration with params [0.00020881 0.20584834]
# Running iteration with params [2.01870510e-04 2.05131274e-01]
# Running iteration with params [0.00020995 0.20580127]
# Running iteration with params [2.02595126e-04 2.05226792e-01]
# Running iteration with params [0.00020895 0.20580081]
# Running iteration with params [2.03639532e-04 2.05298659e-01]
# Running iteration with params [1.98012674e-04 2.04820157e-01]
# Running iteration with params [0.00020567 0.20548401]
# Running iteration with params [2.04625250e-04 2.05412143e-01]
# Running iteration with params [2.01550719e-04 2.05154926e-01]
# Running iteration with params [2.04639922e-04 2.05401739e-01]
# Running iteration with params [2.02609798e-04 2.05216388e-01]
# Running iteration with params [2.04121387e-04 2.05363204e-01]
# Running iteration with params [0.00020617 0.20553815]
# Running iteration with params [2.03487890e-04 2.05304632e-01]
# Optimization terminated successfully.
#          Current function value: 6.154568
#          Iterations: 81
#          Function evaluations: 147
# Running iteration with params [0.0002279  0.20530463]
# Running iteration with params [2.03487890e-04 2.05304632e-01]
# Running iteration with params [2.03487890e-04 2.05304632e-01]
# Running iteration with params [1.79073828e-04 2.05304632e-01]
# Running iteration with params [0.00021569 0.20532969]
# Running iteration with params [0.00021569 0.20527957]
# Running iteration with params [1.91280859e-04 2.05329693e-01]
# Running iteration with params [1.91280859e-04 2.05279570e-01]
# Running iteration with params [2.03487890e-04 2.05354755e-01]
# Running iteration with params [2.03487890e-04 2.05304632e-01]
# Running iteration with params [2.03487890e-04 2.05304632e-01]
# Running iteration with params [2.03487890e-04 2.05254509e-01]
# Running iteration with params [2.03487890e-04 2.05304632e-01]
#                               TheoryFit Results
# ==============================================================================
# Dep. Variable:                      y   Log-Likelihood:            -2.5669e+06
# Model:                      TheoryFit   AIC:                         5.134e+06
# Method:            Maximum Likelihood   BIC:                         5.134e+06
# Date:                Fri, 26 Jun 2026
# Time:                        12:01:39
# No. Observations:              417074
# Df Residuals:                  417072
# Df Model:                           2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# par0           0.0002   1.02e-05     19.896      0.000       0.000       0.000
# par1           0.2053      0.001    229.599      0.000       0.204       0.207
# ==============================================================================

# %%
mle_model.bic
# Out:
# np.float64(5133872.009271734)

# %%
# 1.6290 0.6006 for LAD min = 2

alphas_hist = np.geomspace(1, 1e6, 100)
alphas = np.geomspace(1, 1e6, 1000)

counts, bins, _ = plt.hist(fit.cleaned_data.collect()["alpha"].to_numpy(),
                           alphas_hist, density = True)

fit_params = WeibullFitParams(*mle_model.params)
# fit_params = WeibullFitParams(lambda_ = 0.5, k = 0.4)
plt.plot(alphas, fit.F_norm(alphas, fit_params), label = r"$F_{\text{W}}$")

plt.ylim(1e-7, counts.max() * 10)
plt.xlim(fit.plot_range[0] * 0.7, fit.plot_range[1] * 0.5)
plt.xscale("log")
plt.xlabel(r"$\alpha$")
plt.yscale("log")
plt.ylabel("Det. probability density")
plt.legend()
plt.grid(which='both', linestyle='-', linewidth=0.4, alpha=0.2)
plt.tight_layout()
plt.savefig("overall_fit.png")
plt.show()

# %%
bin_centers = 0.5 * (dp.Phi_counts_smoothed_bins[:-1] + dp.Phi_counts_smoothed_bins[1:])
bin_widths = np.abs(dp.Phi_counts_smoothed_bins[:-1] - dp.Phi_counts_smoothed_bins[1:])
mask = (dp.Phi_counts_smoothed_counts / bin_widths > 10**3) & (dp.Phi_counts_smoothed_counts * bin_widths > 10**3)
plt.plot(bin_centers[mask], dp.Phi_counts_smoothed_counts[mask], label = "Mesh (smoothed)")

bin_centers = 0.5 * (dp.Phi_counts_sphere_noisy_bins[:-1] + dp.Phi_counts_sphere_noisy_bins[1:])
mask = dp.Phi_counts_sphere_noisy_counts != 0
plt.plot(bin_centers[mask], dp.Phi_counts_sphere_noisy_counts[mask], label = "sphere (noisy)")

bin_centers = 0.5 * (dp.Phi_counts_sphere_theory_bins[:-1] + dp.Phi_counts_sphere_theory_bins[1:])
mask = dp.Phi_counts_sphere_theory_counts != 0
plt.plot(bin_centers[mask], dp.Phi_counts_sphere_theory_counts[mask], label = "sphere (theory)")

plt.xscale("log")
plt.yscale("log")
plt.legend()
