# %%
import matplotlib.pyplot as plt
from statsmodels.base.model import GenericLikelihoodModel
import numpy as np
import cv2
import scienceplots
import tifffile as tiff

from boulder_statistics.analysis.data_product_encyclopedia import DataProductEncyclopedia
from boulder_statistics.analysis.power_law_fit_params import PowerLawFitParams
from boulder_statistics.analysis.weibull_fit_params import WeibullFitParams

plt.style.use('science')
plt.rcParams["figure.figsize"] = (3.5, 3.5 * ((5**0.5 - 1) / 2)) # 3.5
plt.rcParams["figure.dpi"] = 600
# %matplotlib inline

import polars as pl
from polars import Expr, LazyFrame, DataFrame
import numpy as np
from pathlib import Path
from typing import Any
import tifffile
from typing import Dict
from typing import Callable


from boulder_statistics.analysis.data_product_encyclopedia import DataProductEncyclopedia

dp = DataProductEncyclopedia(
    data_products_path=Path(r"C:\Users\Joshu\OneDrive - Nexus365\AO33\Boulder_database\AO33\.data_products"))

# %%
from boulder_statistics.analysis.quick_calculate_Weibull import WeibullFittingFunction

fit = WeibullFittingFunction(dp, LAD_min=0)

# %%
class TheoryFit(GenericLikelihoodModel):
    param_names = ["lambda", "k"]

    def __init__(self, x):
        super().__init__(x)

    def loglikeobs(self, params):
        alphas = self.endog

        fit_params = WeibullFitParams(*params)
        print(f"Ran iteration with params {params}")
        return np.log(fit.F_norm(alphas, fit_params))

    @property
    def start_params(self):
        return np.array([0.1, 0.3])
    
mle_model = TheoryFit(fit.cleaned_data.collect()["alpha"].to_numpy()).fit()

print(mle_model.summary())
mle_model.model.loglikeobs(mle_model.params).mean()
# Out:
# Ran iteration with params [0.1 0.3]
# Ran iteration with params [0.105 0.3  ]
# Ran iteration with params [0.1   0.315]
# Ran iteration with params [0.095 0.315]
# Ran iteration with params [0.09   0.3225]
# Ran iteration with params [0.09   0.3375]
# Ran iteration with params [0.085   0.35625]
# Ran iteration with params [0.075   0.36375]
# Ran iteration with params [0.0625   0.388125]
# Ran iteration with params [0.0575   0.421875]
# Ran iteration with params [0.065625   0.39703125]
# Ran iteration with params [0.043125   0.42890625]
# Ran iteration with params [0.07453125 0.37441406]
# Ran iteration with params [0.05359375 0.41074219]
# Ran iteration with params [0.06929688 0.38349609]
# Ran iteration with params [0.07242188 0.39240234]
# Ran iteration with params [0.07738281 0.39454102]
# Ran iteration with params [0.08105469 0.38100586]
# Ran iteration with params [0.06948242 0.3930249 ]
# Ran iteration with params [0.07756836 0.40406982]
# Ran iteration with params [0.0817041  0.41435669]
# Ran iteration with params [0.08960449 0.4158728 ]
# Ran iteration with params [0.09966553 0.42729675]
# Ran iteration with params [0.10398682 0.44711243]
# Ran iteration with params [0.11728882 0.47339813]
# Ran iteration with params [0.13525024 0.4863382 ]
# Ran iteration with params [0.16202332 0.52232895]
# Ran iteration with params [0.17964661 0.56843033]
# Ran iteration with params [0.21963715 0.63899712]
# Ran iteration with params [0.2243811  0.61736115]
# Ran iteration with params [0.19760803 0.58137039]
# Ran iteration with params [0.21523132 0.62747177]
# Ran iteration with params [0.17532532 0.54861465]
# Ran iteration with params [0.20192932 0.60118607]
# Ran iteration with params [0.18197632 0.56175751]
# Ran iteration with params [0.19993774 0.57469757]
# Ran iteration with params [0.18471939 0.56999714]
# Ran iteration with params [0.16908768 0.55038425]
# Ran iteration with params [0.19047794 0.57362386]
# Ran iteration with params [0.18773487 0.56538423]
# Ran iteration with params [0.18924261 0.56307777]
# Ran iteration with params [0.1962365  0.57725058]
# Ran iteration with params [0.18554136 0.56563077]
# Ran iteration with params [0.18279829 0.55739114]
# Ran iteration with params [0.18855803 0.56956568]
# Ran iteration with params [0.18636452 0.56981223]
# Ran iteration with params [0.18739228 0.56649123]
# Ran iteration with params [0.19040895 0.57042613]
# Ran iteration with params [0.18675826 0.56682961]
# Ran iteration with params [0.18559251 0.56375516]
# Ran iteration with params [0.18781665 0.56811305]
# Ran iteration with params [0.18718263 0.56845144]
# Ran iteration with params [0.18733987 0.56698128]
# Ran iteration with params [0.18839826 0.56826471]
# Ran iteration with params [0.18716826 0.56718839]
# Ran iteration with params [0.18764504 0.56832016]
# Ran iteration with params [0.18741616 0.567316  ]
# Ran iteration with params [0.18676777 0.56639134]
# Ran iteration with params [0.18755443 0.56768262]
# Ran iteration with params [0.18780233 0.56781023]
# Ran iteration with params [0.18732678 0.56734385]
# Ran iteration with params [0.18746505 0.56771047]
# Ran iteration with params [0.1876927  0.56804924]
# Ran iteration with params [0.18741826 0.5675202 ]
# Ran iteration with params [0.18750764 0.56749235]
# Ran iteration with params [0.18749699 0.56754688]
# Ran iteration with params [0.18736082 0.56738446]
# Ran iteration with params [0.18750603 0.56760808]
# Optimization terminated successfully.
#          Current function value: 6.322947
#          Iterations: 34
#          Function evaluations: 68
# Ran iteration with params [0.18746402 0.5675202 ]
# Ran iteration with params [0.18741826 0.5675202 ]
# Ran iteration with params [0.18741826 0.5675202 ]
# Ran iteration with params [0.1873725 0.5675202]
# Ran iteration with params [0.18744114 0.56758948]
# Ran iteration with params [0.18744114 0.56745092]
# Ran iteration with params [0.18739538 0.56758948]
# Ran iteration with params [0.18739538 0.56745092]
# Ran iteration with params [0.18741826 0.56765875]
# Ran iteration with params [0.18741826 0.5675202 ]
# Ran iteration with params [0.18741826 0.5675202 ]
# Ran iteration with params [0.18741826 0.56738164]
# Ran iteration with params [0.18741826 0.5675202 ]
#                               TheoryFit Results
# ==============================================================================
# Dep. Variable:                      y   Log-Likelihood:            -2.6942e+06
# Model:                      TheoryFit   AIC:                         5.388e+06
# Method:            Maximum Likelihood   BIC:                         5.388e+06
# Date:                Thu, 25 Jun 2026
# Time:                        15:45:46
# No. Observations:              426096
# Df Residuals:                  426094
# Df Model:                           2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# par0           0.1874      0.001    227.789      0.000       0.186       0.189
# par1           0.5675      0.001    488.342      0.000       0.565       0.570
# ==============================================================================
# Ran iteration with params [0.18741826 0.5675202 ]
# np.float64(-6.322947104587902)

# %%
# 1.6290 0.6006 for LAD min = 2

alphas_hist = np.geomspace(1, 1e6, 100)
alphas = np.geomspace(1, 1e6, 1000)

counts, bins, _ = plt.hist(fit.cleaned_data.collect()["alpha"].to_numpy(),
                           alphas_hist, density = True)

fit_params = WeibullFitParams(*mle_model.params)
# fit_params = WeibullFitParams(lambda_ = 0.5, k = 0.4)
plt.plot(alphas, fit.F_norm(alphas, fit_params), label = r"$F(\alpha|\omega)$")

plt.ylim(1e-7, counts.max() * 1.5)
# plt.xlim(fit.plot_range[0] * 0.7, fit.plot_range[1] * 0.5)
plt.xscale("log")
plt.xlabel(r"$\alpha$")
plt.yscale("log")
plt.ylabel("Det. probability density")
plt.legend()
plt.grid(which='both', linestyle='-', linewidth=0.4, alpha=0.2)
plt.tight_layout()
plt.savefig("overall_fit.png")
plt.show()

# %%
bin_centers = 0.5 * (dp.Phi_counts_smoothed_bins[:-1] + dp.Phi_counts_smoothed_bins[1:])
bin_widths = np.abs(dp.Phi_counts_smoothed_bins[:-1] - dp.Phi_counts_smoothed_bins[1:])
mask = (dp.Phi_counts_smoothed_counts / bin_widths > 10**3) & (dp.Phi_counts_smoothed_counts * bin_widths > 10**3)
plt.plot(bin_centers[mask], dp.Phi_counts_smoothed_counts[mask], label = "Mesh (smoothed)")

bin_centers = 0.5 * (dp.Phi_counts_sphere_noisy_bins[:-1] + dp.Phi_counts_sphere_noisy_bins[1:])
mask = dp.Phi_counts_sphere_noisy_counts != 0
plt.plot(bin_centers[mask], dp.Phi_counts_sphere_noisy_counts[mask], label = "sphere (noisy)")

bin_centers = 0.5 * (dp.Phi_counts_sphere_theory_bins[:-1] + dp.Phi_counts_sphere_theory_bins[1:])
mask = dp.Phi_counts_sphere_theory_counts != 0
plt.plot(bin_centers[mask], dp.Phi_counts_sphere_theory_counts[mask], label = "sphere (theory)")

plt.xscale("log")
plt.yscale("log")
plt.legend()
